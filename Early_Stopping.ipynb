# %% [markdown]
# <a href="https://colab.research.google.com/github/bhattaraijay05/dl/blob/main/Early_Stopping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from pylab import rcParams
import matplotlib.pyplot as plt
import warnings
from mlxtend.plotting import plot_decision_regions
from matplotlib.colors import ListedColormap
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_circles
import seaborn as sns

# %%
X, y = make_circles(n_samples=100, noise=0.1, random_state=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
test_size=0.20, random_state=2)

# %%
model = Sequential()
model.add(Dense(256, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam',
metrics=['accuracy'])
history = model.fit(X_train, y_train, validation_data=(X_test,y_test), epochs=3500, verbose=0)

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
plot_decision_regions(X_test, y_test.ravel(), clf = model, legend=2)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/mlxtend/plotting/decision_regions.py:244: MatplotlibDeprecationWarning: Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.
#   ax.axis(xmin=xx.min(), xmax=xx.max(), y_min=yy.min(), y_max=yy.max())

# %%
model = Sequential()
model.add(Dense(256, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam',
metrics=['accuracy'])
callback = EarlyStopping(
  monitor="val_loss",
  min_delta=0.00001,
  patience=20,
  verbose=1,
  mode="auto",
  baseline=None,
  restore_best_weights=False
  )
history = model.fit(X_train, y_train, validation_data=(X_test,
y_test), epochs=3500, callbacks=callback)
# Out:
# Epoch 1/3500
# 3/3 [==============================] - 1s 91ms/step - loss: 0.6972 - accuracy: 0.5125 - val_loss: 0.7059 - val_accuracy: 0.4000
# Epoch 2/3500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6941 - accuracy: 0.5000 - val_loss: 0.7057 - val_accuracy: 0.3500
# Epoch 3/3500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.6931 - accuracy: 0.5500 - val_loss: 0.7057 - val_accuracy: 0.3500
# Epoch 4/3500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.6916 - accuracy: 0.5250 - val_loss: 0.7077 - val_accuracy: 0.3000
# Epoch 5/3500
# 3/3 [==============================] - 0s 14ms/step - loss: 0.6904 - accuracy: 0.5500 - val_loss: 0.7090 - val_accuracy: 0.3000
# Epoch 6/3500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6892 - accuracy: 0.5625 - val_loss: 0.7102 - val_accuracy: 0.3000
# Epoch 7/3500
# 3/3 [==============================] - 0s 14ms/step - loss: 0.6886 - accuracy: 0.5500 - val_loss: 0.7114 - val_accuracy: 0.3000
# Epoch 8/3500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6875 - accuracy: 0.5500 - val_loss: 0.7129 - val_accuracy: 0.3000
# Epoch 9/3500
# 3/3 [==============================] - 0s 14ms/step - loss: 0.6869 - accuracy: 0.5500 - val_loss: 0.7150 - val_accuracy: 0.3000
# Epoch 10/3500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6863 - accuracy: 0.5375 - val_loss: 0.7168 - val_accuracy: 0.3000
# Epoch 11/3500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6858 - accuracy: 0.5375 - val_loss: 0.7184 - val_accuracy: 0.3000
# Epoch 12/3500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6848 - accuracy: 0.5375 - val_loss: 0.7195 - val_accuracy: 0.3500
# Epoch 13/3500
# 3/3 [==============================] - 0s 14ms/step - loss: 0.6844 - accuracy: 0.5500 - val_loss: 0.7198 - val_accuracy: 0.4000
# Epoch 14/3500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6836 - accuracy: 0.5500 - val_loss: 0.7198 - val_accuracy: 0.4000
# Epoch 15/3500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6829 - accuracy: 0.5375 - val_loss: 0.7196 - val_accuracy: 0.4500
# Epoch 16/3500
# 3/3 [==============================] - 0s 21ms/step - loss: 0.6823 - accuracy: 0.5500 - val_loss: 0.7188 - val_accuracy: 0.4500
# Epoch 17/3500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.6819 - accuracy: 0.5500 - val_loss: 0.7180 - val_accuracy: 0.4500
# Epoch 18/3500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.6815 - accuracy: 0.5625 - val_loss: 0.7178 - val_accuracy: 0.4500
# Epoch 19/3500
# 3/3 [==============================] - 0s 14ms/step - loss: 0.6809 - accuracy: 0.5750 - val_loss: 0.7164 - val_accuracy: 0.4000
# Epoch 20/3500
# 3/3 [==============================] - 0s 24ms/step - loss: 0.6802 - accuracy: 0.5750 - val_loss: 0.7165 - val_accuracy: 0.4000
# Epoch 21/3500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6799 - accuracy: 0.5750 - val_loss: 0.7169 - val_accuracy: 0.4000
# Epoch 22/3500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6791 - accuracy: 0.5750 - val_loss: 0.7165 - val_accuracy: 0.4000
# Epoch 22: early stopping

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
plot_decision_regions(X_test, y_test.ravel(), clf = model, legend=2)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/mlxtend/plotting/decision_regions.py:244: MatplotlibDeprecationWarning: Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.
#   ax.axis(xmin=xx.min(), xmax=xx.max(), y_min=yy.min(), y_max=yy.max())
